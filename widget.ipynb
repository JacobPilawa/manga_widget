# %%
from package.analyze import run_kinematics
from package.analyze import run_metallicity
import warnings
warnings.filterwarnings('ignore')
# %matplotlib notebook
# Out:
# [INFO]: No release version set. Setting default to DR15
# [WARNING]: path /Users/jacobpilawa/sas/mangawork/manga/spectro/analysis/v2_4_3/2.2.1/dapall-v2_4_3-2.2.1.fits cannot be found. Setting dapall to None. (MarvinUserWarning)
# [WARNING]: numpy.ndarray size changed, may indicate binary incompatibility. Expected 80 from C header, got 88 from PyObject (RuntimeWarning)

# %%
object_name = '8711-6102' # A GOOD ONE!
kinematic_save_dir = 'kinematic_plots/' # name of directory to save plots; will auto-create!

# %%
run_kinematics(object_name,  kinematic_save_dir)
# Out:
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="700">
# <img src="data:image/png;base64,..." width="929">

# %%
object_name = '8077-6104' # A GOOD ONE!
metallicty_save_dir = 'metallicity_plots/' # name of directory to save plots; will auto-create!

# %%
run_metallicity(object_name, metallicty_save_dir)
# Out:
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="850">
# <img src="data:image/png;base64,..." width="971">
# <img src="data:image/png;base64,..." width="934">
# <img src="data:image/png;base64,..." width="600">
